# %%
import numpy as np

# %%
q_table_40 = {}
for purchase in range(0, 4100, 100):
    for list_price in range(0, 4100, 100):
        for customer_traffic in range(0, 41):
            for competitiveness in range(0, 41):
                q_table_40[(purchase, 
                            list_price, 
                            round(customer_traffic*0.125,1), 
                            round(competitiveness*0.0625,2))] = [np.random.uniform(-5, 0) for i in range(5)]

# %%
q_table_20 = {}
for purchase in range(0, 4200, 200):
    for list_price in range(0, 4200, 200):
        for customer_traffic in range(0, 21):
            for competitiveness in range(0, 21):
                q_table_20[(purchase, 
                            list_price, 
                            round(customer_traffic*0.25,1), 
                            round(competitiveness*0.125,1))] = [np.random.uniform(-5, 0) for i in range(5)]

# %%
np.save('q_table_40.npy', q_table_40)
np.save('q_table_50.npy', q_table_50)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
q_table_30_1800_5acts = {}
for purchase in range(0, 1830, 30):
    for list_price in range(0, 1830, 30):
        for customer_traffic in range(0, 61):
            for competitiveness in range(0, 61):
                q_table_30_1800_5acts[(purchase, 
                            list_price, 
                            round(customer_traffic*0.0833,1), 
                            round(competitiveness*0.0416,2))] = [np.random.uniform(-5, 0) for i in range(5)]
np.save("/content/drive/My Drive/Colab Notebooks/dynamic_pricing/data/qtable/q_table_60.npy",  q_table_30_1800_5acts)

# %% [markdown]
# ### $\color{red}{\text{Q-Tables for 3 Actions}}$

# %%
q_table_100_4000_3acts = {}
for purchase in range(0, 4100, 100):
    for list_price in range(0, 4100, 100):
        for customer_traffic in range(0, 41):
            for competitiveness in range(0, 41):
                q_table_100_4000_3acts[(purchase, 
                            list_price, 
                            round(customer_traffic*0.125,1), 
                            round(competitiveness*0.0625,2))] = [np.random.uniform(-3, 0) for i in range(3)]

# %%
q_table_50_4050_3acts = {}
for purchase in range(0, 4050, 50):
    for list_price in range(0, 4050, 50):
        for customer_traffic in range(0, 81):
            for competitiveness in range(0, 81):
                q_table_50_4050_3acts[(purchase, 
                            list_price, 
                            round(customer_traffic*0.0625,1), 
                            round(competitiveness*0.03125,2))] = [np.random.uniform(-3, 0) for i in range(3)]

# %%
q_table_100_1800_3acts = {}
for purchase in range(0, 1900, 100):
    for list_price in range(0, 1900, 100):
        for customer_traffic in range(0, 19):
            for competitiveness in range(0, 19):
               q_table_100_1800_3acts[(purchase, 
                            list_price, 
                            round(customer_traffic*0.2778,1), 
                            round(competitiveness*0.1389,2))] = [np.random.uniform(-3, 0) for i in range(3)]

# %%
q_table_50_1800_3acts = {}
for purchase in range(0, 1850, 50):
    for list_price in range(0, 1850, 50):
        for customer_traffic in range(0, 37):
            for competitiveness in range(0, 37):
                q_table_50_1800_3acts[(purchase, 
                            list_price, 
                            round(customer_traffic*0.1389,1), 
                            round(competitiveness*0.0695,2))] = [np.random.uniform(-3, 0) for i in range(3)]

# %%
q_table_30_1800_3acts = {}
for purchase in range(0, 1830, 30):
    for list_price in range(0, 1830, 30):
        for customer_traffic in range(0, 61):
            for competitiveness in range(0, 61):
                q_table_30_1800_3acts[(purchase, 
                            list_price, 
                            round(customer_traffic*0.0833,1), 
                            round(competitiveness*0.0416,2))] = [np.random.uniform(-3, 0) for i in range(3)]

# %%
np.save('q_table_100_4000_3acts.npy', q_table_100_4000_3acts)
np.save('q_table_50_4050_3acts.npy',  q_table_50_4050_3acts)
np.save('q_table_100_1800_3acts.npy', q_table_100_1800_3acts)
np.save('q_table_50_1800_3acts.npy',  q_table_50_1800_3acts)
np.save('q_table_30_1800_3acts.npy',  q_table_30_1800_3acts)
